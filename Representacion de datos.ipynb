# %%
import numpy as np
import matplotlib.pyplot as plt
import re

data = [
    './data_local/salida',
    './data_local/salida_2',
    './data_local/salida_4'
]
labels = ['serial', 'OMP_NUM_THREADS=2','OMP_NUM_THREADS=4']
colors = ['red', 'green', 'blue']
fig, ax = plt.subplots()
for i, x in enumerate(data):
    fname = x
    with open(fname) as f:
        content = f.readlines()
        content = [x.rstrip() for x in content] 
        a = np.array([x for i, x in enumerate(content) if not (i % 4 == 0)])
        a = a.astype(np.double)
        a = a.reshape((30,3))
        a = [ x.sum()/3 for x in a] 
        ax.scatter([x for x in range(100,3100,100)], a, c=colors[i],label=labels[i],  alpha=0.5)

# %%
ax.set_title('Host local')
ax.set_ylabel('Tiempo en milisegundos')
ax.set_xlabel('n varibles')
ax.legend()
ax.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import re

data = [
    './data_guane/salida',
    './data_guane/salida_2',
    './data_guane/salida_4',
    './data_guane/salida_8',
    './data_guane/salida_16',
    './data_guane/salida_24'
]
labels = [
    'serial', 
    'OMP_NUM_THREADS=2',
    'OMP_NUM_THREADS=4',
    'OMP_NUM_THREADS=8',
    'OMP_NUM_THREADS=16',
    'OMP_NUM_THREADS=24'
]
colors = ['red', 'green', 'blue', 'orange', 'yellow', 'pink']
fig, ax = plt.subplots()
for i, x in enumerate(data):
    fname = x
    with open(fname) as f:
        content = f.readlines()
        content = [x.rstrip() for x in content] 
        a = np.array([x for i, x in enumerate(content) if not (i % 4 == 0)])
        a = a.astype(np.double)
        a = a.reshape((30,3))
        a = [ x.sum()/3 for x in a] 
        ax.scatter([x for x in range(100,3100,100)], a, c=colors[i],label=labels[i],   alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-747d0901a706> in <module>()
#      23 for i, x in enumerate(data):
#      24     fname = x
# ---> 25     with open(fname) as f:
#      26         content = f.readlines()
#      27         content = [x.rstrip() for x in content]
#
# FileNotFoundError: [Errno 2] No such file or directory: './data_guane/salida'

# %%
ax.set_title('Host guene 13')
ax.set_ylabel('Tiempo en milisegundos')
ax.set_xlabel('n varibles')
ax.legend()
ax.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import re

data = [
    './data_guane/salida',
    './data_guane/salida_24',
    './data_guane/salida_16',
    './data_guane/salida_8',
    './data_guane/salida_4',
    './data_guane/salida_2'
]
labels = [
    'serial', 
    'OMP_NUM_THREADS=2',
    'OMP_NUM_THREADS=4',
    'OMP_NUM_THREADS=8',
    'OMP_NUM_THREADS=16',
    'OMP_NUM_THREADS=24'
]
colors = ['red', 'green', 'blue', 'orange', 'yellow', 'pink']
fig, ax = plt.subplots()
for i, x in enumerate(data):
    fname = x
    with open(fname) as f:
        content = f.readlines()
        content = [x.rstrip() for x in content] 
        a = np.array([x for i, x in enumerate(content) if not (i % 4 == 0)])
        a = a.astype(np.double)
        a = a.reshape((30,3))
        a = [ x.sum()/3 for x in a] 
        print(a[24:24+3])
        ax.scatter([x for x in range(2500,2800,100)], a[24:24+3], c=colors[i],label=labels[i], s= (i * 100) + 100,  alpha=1)
# Out:
# [42447.101354598999, 47776.985565821327, 53461.959600448608]
# [54015.033333333333, 60862.533333333326, 68164.900000000009]
# [54028.966666666667, 60890.933333333327, 68218.933333333334]
# [54134.900000000001, 60904.299999999996, 68211.800000000003]
# [54077.200000000004, 60928.133333333331, 68163.800000000003]
# [54107.166666666664, 60921.766666666663, 68223.533333333326]

# %%
ax.set_title('Host guene 13')
ax.set_ylabel('Tiempo en milisegundos')
ax.set_xlabel('n varibles')
ax.legend()
ax.grid(True)
plt.show()
